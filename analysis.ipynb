# %%
from load_data import load_h5_to_dict
import numpy as np
import matplotlib.pyplot as plt
import re
import os
import sys
import h5py
from unit_processor import *

module_path = os.path.abspath(os.path.join('..', 'Git/RFAnalysis/sta_analysis/sta_analysis'))
if module_path not in sys.path:
    sys.path.append(module_path)

from receptive_field_filter import *
from receptive_field_analysis import *
from util_plotting import *
from correlations import *


config_file = "config.toml"
with open(config_file, "r") as f:
    config = toml.load(f)

start = config["st_calculation"]["start"]
end = config["st_calculation"]["end"]

h5_dir = 'data/h5_for_sta'
led_dir = 'data/led_for_sta'

h5_file = '2024-11-26T10-23-28_RecID-496_I23775_KG_poisson025-62p5ms_15moff-15mon-15moff-3x-260son-270soff-alternating-stimulus_5p5V_DIV22_HS258_spikesonly.h5'
led_file = 'detailed_sync_2024-11-26T10-23-28_RecID-496_I23775_KG_poisson025-62p5ms_15moff-15mon-15moff-3x-260son-270soff-alternating-stimulus_5p5V_DIV22_HS258_only-de_2025-06-04_12-32-38.npz'
rec_id = 496

h5_filename = os.path.join(h5_dir, h5_file)
led_filename = os.path.join(led_dir, led_file)
data_dict = load_h5_to_dict(h5_filename)
led_data = np.load(led_filename)
analysis = UnitProcessor(data_dict, led_data, config_file = config_file, rec_id = rec_id, verbose = False)
analysis.process_all_units()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 39
#      37 led_data = np.load(led_filename)
#      38 analysis = UnitProcessor(data_dict, led_data, config_file = config_file, rec_id = rec_id, verbose = False)
# ---> 39 analysis.process_all_units()
#
# File /mnt/vast-standard/home/lasloaddy.bode/u16892/Analysis/unit_processor.py:128, in UnitProcessor.process_all_units(self)
#     126 self.logger.info("Processing all units\n")
#     127 for key in self.data_dict.keys():
# --> 128     self.process_unit(key)
#
# File /mnt/vast-standard/home/lasloaddy.bode/u16892/Analysis/unit_processor.py:195, in UnitProcessor.process_unit(self, key)
#     193 plt.legend()
#     194 if self.save_plots:
# --> 195     plt.savefig(os.path.join(self.plot_folder, f"Rec-ID_{self.rec_id}_{key}_spiketimes.pdf"), dpi=600)
#     196 plt.show()
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backends/backend_pdf.py:2786, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2781 file.newPage(width, height)
#    2782 renderer = MixedModeRenderer(
#    2783     self.figure, width, height, dpi,
#    2784     RendererPdf(file, dpi, height, width),
#    2785     bbox_inches_restore=bbox_inches_restore)
# -> 2786 self.figure.draw(renderer)
#    2787 renderer.finalize()
#    2788 if not isinstance(filename, PdfPages):
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/axes/_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/collections.py:430, in Collection.draw(self, renderer)
#     421         ipaths, ilinestyles = self._get_inverse_paths_linestyles()
#     422         renderer.draw_path_collection(
#     423             gc, transform.frozen(), ipaths,
#     424             self.get_transforms(), offsets, offset_trf,
#    (...)    427             self._antialiaseds, self._urls,
#     428             "screen")
# --> 430     renderer.draw_path_collection(
#     431         gc, transform.frozen(), paths,
#     432         self.get_transforms(), offsets, offset_trf,
#     433         self.get_facecolor(), self.get_edgecolor(),
#     434         self._linewidths, self._linestyles,
#     435         self._antialiaseds, self._urls,
#     436         "screen")  # offset_position, kept for backcompat.
#     438 gc.restore()
#     439 renderer.close_group(self.__class__.__name__)
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backends/backend_pdf.py:2071, in RendererPdf.draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offset_trans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#    2067 should_do_optimization = \
#    2068     len_path + uses_per_path + 5 < len_path * uses_per_path
#    2070 if (not can_do_optimization) or (not should_do_optimization):
# -> 2071     return RendererBase.draw_path_collection(
#    2072         self, gc, master_transform, paths, all_transforms,
#    2073         offsets, offset_trans, facecolors, edgecolors,
#    2074         linewidths, linestyles, antialiaseds, urls,
#    2075         offset_position)
#    2077 padding = np.max(linewidths)
#    2078 path_codes = []
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backend_bases.py:249, in RendererBase.draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offset_trans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#     247     transform = transform.frozen()
#     248     transform.translate(xo, yo)
# --> 249 self.draw_path(gc0, path, transform, rgbFace)
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backends/backend_pdf.py:2024, in RendererPdf.draw_path(self, gc, path, transform, rgbFace)
#    2021 def draw_path(self, gc, path, transform, rgbFace=None):
#    2022     # docstring inherited
#    2023     self.check_gc(gc, rgbFace)
# -> 2024     self.file.writePath(
#    2025         path, transform,
#    2026         rgbFace is None and gc.get_hatch_path() is None,
#    2027         gc.get_sketch_params())
#    2028     self.file.output(self.gc.paint())
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backends/backend_pdf.py:1894, in PdfFile.writePath(self, path, transform, clip, sketch)
#    1892     clip = None
#    1893     simplify = False
# -> 1894 cmds = self.pathOperations(path, transform, clip, simplify=simplify,
#    1895                            sketch=sketch)
#    1896 self.output(*cmds)
#
# File ~/.conda/envs/jupyter_env/lib/python3.13/site-packages/matplotlib/backends/backend_pdf.py:1880, in PdfFile.pathOperations(path, transform, clip, simplify, sketch)
#    1878 @staticmethod
#    1879 def pathOperations(path, transform, clip=None, simplify=None, sketch=None):
# -> 1880     return [Verbatim(_path.convert_to_string(
#    1881         path, transform, clip, simplify, sketch,
#    1882         6,
#    1883         [Op.moveto.value, Op.lineto.value, b'', Op.curveto.value,
#    1884          Op.closepath.value],
#    1885         True))]
#
# KeyboardInterrupt:

# %%
from load_data import load_h5_to_dict
import numpy as np
import matplotlib.pyplot as plt
import re
import os
import sys
import h5py
from unit_processor import *

module_path = os.path.abspath(os.path.join('..', 'Git/RFAnalysis/sta_analysis/sta_analysis'))
if module_path not in sys.path:
    sys.path.append(module_path)

from receptive_field_filter import *
from receptive_field_analysis import *
from util_plotting import *
from correlations import *


config_file = "config.toml"
with open(config_file, "r") as f:
    config = toml.load(f)

start = config["st_calculation"]["start"]
end = config["st_calculation"]["end"]

h5_dir = 'data/h5_for_sta'
led_dir = 'data/led_for_sta'


def extract_rec_id(filename):
    match = re.search(r"RecID-(\d+)", filename)
    if match:
        return int(match.group(1))
    return None

h5_files = {extract_rec_id(f): os.path.join(h5_dir, f)
            for f in os.listdir(h5_dir)
            if f.endswith(".h5") and extract_rec_id(f) is not None}

led_files = {extract_rec_id(f): os.path.join(led_dir, f)
             for f in os.listdir(led_dir)
             if f.endswith(".npz") and extract_rec_id(f) is not None}

common_rec_ids = sorted(set(h5_files.keys()) & set(led_files.keys()))

print(f"Found {len(common_rec_ids)} matching file pairs")

for rec_id in common_rec_ids:
    h5_filename = h5_files[rec_id]
    led_filename = led_files[rec_id]

    print(f"\nProcessing RecID {rec_id}")
    print(f"  H5 file:  {os.path.basename(h5_filename)}")
    print(f"  LED file: {os.path.basename(led_filename)}")

    # Load data
    data_dict = load_h5_to_dict(h5_filename)
    led_data = np.load(led_filename)

    # Run analysis
    processor = UnitProcessor(data_dict, led_data, config_file=config_file, rec_id = rec_id, verbose=True)
    processor.process_all_units()
# Out:
# Found 24 matching file pairs
#
# Processing RecID 65
#   H5 file:  2024-10-01T13-11-50_RecID-065_I23773_KG_poisson025-62p5ms_15moff-15mon-15moff_5p7V_DIV22_HS32_spikesonly.h5
#   LED file: detailed_sync_2024-10-01T13-11-50_RecID-065_I23773_KG_poisson025-62p5ms_15moff-15mon-15moff_5p7V_DIV22_HS32_only-de_2025-06-04_12-32-38.npz
# Processing all units
#
# Processing Unit Channel_13_2
#
# Channel_13_2 skipped. (inhibited)
#
# Processing Unit Channel_14_1
#
# Channel_14_1 skipped. (inhibited)
#
# Processing Unit Channel_14_2
#
# Channel_14_2 skipped. (inhibited)
#
# Processing Unit Channel_21_1
#
# Channel_21_1 skipped. (inhibited)
#
# Processing Unit Channel_21_2
#
# Channel_21_2 skipped. (inhibited)
#
# Processing Unit Channel_22_1
#
# Channel_22_1 skipped. (inhibited)
#
# Processing Unit Channel_22_2
#
# Channel_22_2 skipped. (inhibited)
#
# Processing Unit Channel_22_3
#
# Channel_22_3 skipped. (inhibited)
#
# Processing Unit Channel_22_4
#
# Channel_22_4 skipped. (inhibited)
#
# Processing Unit Channel_23_1
#
# Channel_23_1 skipped. (inhibited)
#
# Processing Unit Channel_23_2
#
# Channel_23_2 skipped. (inhibited)
#
# Processing Unit Channel_26_1
#
# Channel_26_1 has 10588 outside and 8968 spikes in stimulus windows
# Inside FR: 9.833 Hz, Outside FR: 5.936 Hz
# Total inside duration: 912.066 s, outside duration: 1783.556 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_26_3
#
# Channel_26_3 skipped. (inhibited)
#
# Processing Unit Channel_28_1
#
# Channel_28_1 has 5059 outside and 9268 spikes in stimulus windows
# Inside FR: 10.162 Hz, Outside FR: 2.837 Hz
# Total inside duration: 912.066 s, outside duration: 1783.498 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_28_2
#
# Channel_28_2 skipped. (inhibited)
#
# Processing Unit Channel_31_1
#
# Channel_31_1 skipped. (inhibited)
#
# Processing Unit Channel_31_2
#
# Channel_31_2 skipped. (barely active)
#
# Processing Unit Channel_32_1
#
# Channel_32_1 skipped. (inhibited)
#
# Processing Unit Channel_32_2
#
# Channel_32_2 skipped. (inhibited)
#
# Processing Unit Channel_34_1
#
# Channel_34_1 skipped. (inhibited)
#
# Processing Unit Channel_34_2
#
# Channel_34_2 skipped. (inhibited)
#
# Processing Unit Channel_34_3
#
# Channel_34_3 skipped. (barely active)
#
# Processing Unit Channel_35_2
#
# Channel_35_2 skipped. (inhibited)
#
# Processing Unit Channel_38_1
#
# Channel_38_1 skipped. (inhibited)
#
# Processing Unit Channel_38_4
#
# Channel_38_4 skipped. (barely active)
#
# Processing Unit Channel_41_1
#
# Channel_41_1 skipped. (inhibited)
#
# Processing Unit Channel_41_2
#
# Channel_41_2 skipped. (inhibited)
#
# Processing Unit Channel_42_1
#
# Channel_42_1 skipped. (inhibited)
#
# Processing Unit Channel_42_2
#
# Channel_42_2 skipped. (inhibited)
#
# Processing Unit Channel_43_1
#
# Channel_43_1 skipped. (inhibited)
#
# Processing Unit Channel_43_2
#
# Channel_43_2 skipped. (inhibited)
#
# Processing Unit Channel_43_3
#
# Channel_43_3 skipped. (inhibited)
#
# Processing Unit Channel_43_4
#
# Channel_43_4 skipped. (barely active)
#
# Processing Unit Channel_44_1
#
# Channel_44_1 skipped. (inhibited)
#
# Processing Unit Channel_44_3
#
# Channel_44_3 skipped. (inhibited)
#
# Processing Unit Channel_44_4
#
# Channel_44_4 skipped. (inhibited)
#
# Processing Unit Channel_46_3
#
# Channel_46_3 skipped. (inhibited)
#
# Processing Unit Channel_46_5
#
# Skipping Channel_46_5: no spikes in stimulus periods
#
# Processing Unit Channel_47_1
#
# Channel_47_1 skipped. (inhibited)
#
# Processing Unit Channel_47_2
#
# Channel_47_2 has 5789 outside and 3728 spikes in stimulus windows
# Inside FR: 4.087 Hz, Outside FR: 3.246 Hz
# Total inside duration: 912.066 s, outside duration: 1783.513 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_48_1
#
# Channel_48_1 skipped. (inhibited)
#
# Processing Unit Channel_52_2
#
# Channel_52_2 skipped. (inhibited)
#
# Processing Unit Channel_53_1
#
# Channel_53_1 skipped. (barely active)
#
# Processing Unit Channel_54_1
#
# Channel_54_1 skipped. (inhibited)
#
# Processing Unit Channel_54_3
#
# Skipping Channel_54_3: no spikes in stimulus periods
#
# Processing Unit Channel_61_1
#
# Channel_61_1 has 2355 outside and 1364 spikes in stimulus windows
# Inside FR: 1.496 Hz, Outside FR: 1.320 Hz
# Total inside duration: 912.066 s, outside duration: 1783.506 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_61_2
#
# Channel_61_2 skipped. (inhibited)
#
# Processing Unit Channel_62_3
#
# Channel_62_3 skipped. (inhibited)
#
# Processing Unit Channel_62_4
#
# Skipping Channel_62_4: no spikes in stimulus periods
#
# Processing Unit Channel_64_1
#
# Channel_64_1 skipped. (inhibited)
#
# Processing Unit Channel_64_2
#
# Channel_64_2 skipped. (inhibited)
#
# Processing Unit Channel_65_1
#
# Channel_65_1 skipped. (inhibited)
#
# Processing Unit Channel_65_2
#
# Channel_65_2 skipped. (inhibited)
#
# Processing Unit Channel_66_1
#
# Channel_66_1 skipped. (inhibited)
#
# Processing Unit Channel_66_2
#
# Channel_66_2 skipped. (inhibited)
#
# Processing Unit Channel_68_1
#
# Channel_68_1 skipped. (inhibited)
#
# Processing Unit Channel_68_2
#
# Channel_68_2 skipped. (inhibited)
#
# Processing Unit Channel_71_2
#
# Channel_71_2 skipped. (inhibited)
#
# Processing Unit Channel_71_3
#
# Channel_71_3 skipped. (barely active)
#
# Processing Unit Channel_73_3
#
# Channel_73_3 skipped. (inhibited)
#
# Processing Unit Channel_75_2
#
# Channel_75_2 skipped. (inhibited)
#
# Processing Unit Channel_75_3
#
# Channel_75_3 skipped. (inhibited)
#
# Processing Unit Channel_76_2
#
# Channel_76_2 skipped. (inhibited)
#
# Processing Unit Channel_77_2
#
# Channel_77_2 skipped. (inhibited)
#
# Processing Unit Channel_78_1
#
# Channel_78_1 skipped. (inhibited)
#
# Processing Unit Channel_78_2
#
# Channel_78_2 skipped. (inhibited)
#
# Processing Unit Channel_82_2
#
# Channel_82_2 has 2669 outside and 1740 spikes in stimulus windows
# Inside FR: 1.908 Hz, Outside FR: 1.496 Hz
# Total inside duration: 912.066 s, outside duration: 1783.501 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_83_1
#
# Channel_83_1 skipped. (inhibited)
#
# Processing Unit Channel_83_2
#
# Channel_83_2 skipped. (barely active)
#
# Processing Unit Channel_84_1
#
# Channel_84_1 skipped. (inhibited)
#
# Processing Unit Channel_84_2
#
# Channel_84_2 skipped. (inhibited)
#
# Processing Unit Channel_85_3
#
# Channel_85_3 skipped. (barely active)
#
# Processing Unit Channel_86_1
#
# Channel_86_1 skipped. (inhibited)
#
# Processing Unit Channel_86_2
#
# Channel_86_2 skipped. (inhibited)
#
# Processing Unit Channel_86_3
#
# Channel_86_3 skipped. (barely active)
#
# Processing Unit Channel_86_4
#
# Channel_86_4 skipped. (inhibited)
#
# Processing Unit Channel_87_1
#
# Channel_87_1 skipped. (barely active)
# Processing RecID 66
#   H5 file:  2024-10-01T14-32-03_RecID-66_I23857_IG_opos-pattern_bars025-83p3ms_10soff-15mon-15moff_5p7V_DIV22_HS221_spikesonly.h5
#   LED file: detailed_sync_2024-10-01T14-32-03_RecID-66_I23857_IG_opos-pattern_bars025-83p3ms_10soff-15mon-15moff_5p7V_DIV22_HS221_only-de_2025-06-04_12-32-38.npz
# Processing all units
#
# Processing Unit Channel_12_1
#
# Channel_12_1 skipped. (barely active)
#
# Processing Unit Channel_12_2
#
# Channel_12_2 skipped. (barely active)
#
# Processing Unit Channel_14_1
#
# Channel_14_1 skipped. (barely active)
#
# Processing Unit Channel_14_2
#
# Channel_14_2 skipped. (barely active)
#
# Processing Unit Channel_16_1
#
# Channel_16_1 skipped. (barely active)
#
# Processing Unit Channel_16_2
#
# Channel_16_2 skipped. (barely active)
#
# Processing Unit Channel_17_1
#
# Channel_17_1 skipped. (barely active)
#
# Processing Unit Channel_17_2
#
# Channel_17_2 skipped. (barely active)
#
# Processing Unit Channel_22_2
#
# Channel_22_2 skipped. (barely active)
#
# Processing Unit Channel_23_2
#
# Channel_23_2 skipped. (barely active)
#
# Processing Unit Channel_31_1
#
# Channel_31_1 has 162 outside and 372 spikes in stimulus windows
# Inside FR: 0.408 Hz, Outside FR: 0.187 Hz
# Total inside duration: 911.911 s, outside duration: 864.991 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_31_2
#
# Channel_31_2 skipped. (barely active)
#
# Processing Unit Channel_32_2
#
# Channel_32_2 skipped. (barely active)
#
# Processing Unit Channel_33_1
#
# Channel_33_1 skipped. (barely active)
#
# Processing Unit Channel_33_2
#
# Channel_33_2 skipped. (barely active)
#
# Processing Unit Channel_35_2
#
# Channel_35_2 skipped. (barely active)
#
# Processing Unit Channel_37_2
#
# Channel_37_2 skipped. (barely active)
#
# Processing Unit Channel_38_1
#
# Channel_38_1 skipped. (barely active)
#
# Processing Unit Channel_38_2
#
# Channel_38_2 skipped. (barely active)
#
# Processing Unit Channel_42_2
#
# Channel_42_2 skipped. (barely active)
#
# Processing Unit Channel_43_2
#
# Channel_43_2 skipped. (barely active)
#
# Processing Unit Channel_48_1
#
# Channel_48_1 skipped. (barely active)
#
# Processing Unit Channel_48_2
#
# Channel_48_2 skipped. (barely active)
#
# Processing Unit Channel_51_2
#
# Channel_51_2 skipped. (barely active)
#
# Processing Unit Channel_51_3
#
# Channel_51_3 skipped. (barely active)
#
# Processing Unit Channel_53_1
#
# Channel_53_1 has 81 outside and 1306 spikes in stimulus windows
# Inside FR: 1.432 Hz, Outside FR: 0.094 Hz
# Total inside duration: 911.911 s, outside duration: 865.057 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_53_2
#
# Channel_53_2 has 27 outside and 545 spikes in stimulus windows
# Inside FR: 0.598 Hz, Outside FR: 0.032 Hz
# Total inside duration: 911.911 s, outside duration: 846.087 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_56_2
#
# Channel_56_2 skipped. (barely active)
#
# Processing Unit Channel_62_1
#
# Channel_62_1 has 148 outside and 929 spikes in stimulus windows
# Inside FR: 1.019 Hz, Outside FR: 0.168 Hz
# Total inside duration: 911.911 s, outside duration: 883.496 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_62_2
#
# Channel_62_2 skipped. (barely active)
#
# Processing Unit Channel_63_1
#
# Channel_63_1 has 808 outside and 2203 spikes in stimulus windows
# Inside FR: 2.416 Hz, Outside FR: 0.915 Hz
# Total inside duration: 911.911 s, outside duration: 882.999 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_63_2
#
# Channel_63_2 has 151 outside and 399 spikes in stimulus windows
# Inside FR: 0.438 Hz, Outside FR: 0.173 Hz
# Total inside duration: 911.911 s, outside duration: 873.112 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_71_1
#
# Channel_71_1 skipped. (barely active)
#
# Processing Unit Channel_71_2
#
# Channel_71_2 skipped. (barely active)
#
# Processing Unit Channel_76_1
#
# Channel_76_1 has 163 outside and 577 spikes in stimulus windows
# Inside FR: 0.633 Hz, Outside FR: 0.185 Hz
# Total inside duration: 911.911 s, outside duration: 881.141 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_76_2
#
# Channel_76_2 skipped. (barely active)
#
# Processing Unit Channel_78_2
#
# Channel_78_2 skipped. (barely active)
#
# Processing Unit Channel_82_1
#
# Channel_82_1 has 142 outside and 487 spikes in stimulus windows
# Inside FR: 0.534 Hz, Outside FR: 0.170 Hz
# Total inside duration: 911.911 s, outside duration: 837.619 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_82_2
#
# Channel_82_2 skipped. (barely active)
#
# Processing Unit Channel_83_1
#
# Channel_83_1 has 63 outside and 618 spikes in stimulus windows
# Inside FR: 0.678 Hz, Outside FR: 0.077 Hz
# Total inside duration: 911.911 s, outside duration: 816.618 s
#
# [0 0 0 ... 0 0 0]
# Processing Unit Channel_83_2
#
# Channel_83_2 skipped. (barely active)
#
# Processing Unit Channel_83_3
#
# Channel_83_3 skipped. (barely active)
# Processing RecID 67
#   H5 file:  2024-10-01T14-32-14_RecID-67_I23775_IG_opos-pattern_poisson025-62p5ms_10soff-15mon-15moff_5p7V_DIV22_HS31_spikesonly.h5
#   LED file: detailed_sync_2024-10-01T14-32-14_RecID-67_I23775_IG_opos-pattern_poisson025-62p5ms_10soff-15mon-15moff_5p7V_DIV22_HS31_only-de_2025-06-04_12-32-38.npz
# Processing all units
#
# Processing Unit Channel_12_2
#
# Channel_12_2 skipped. (barely active)
#
# Processing Unit Channel_13_2
#
# Channel_13_2 skipped. (barely active)
#
# Processing Unit Channel_14_1
#
# Channel_14_1 has 317 outside and 604 spikes in stimulus windows
# Inside FR: 0.662 Hz, Outside FR: 0.362 Hz
# Total inside duration: 911.757 s, outside duration: 876.631 s
#
# [0 0 0 ... 0 0 0]
